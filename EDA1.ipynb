# %% [markdown]
# # Import Dependencies

# %%
# Essentials
import pandas as pd #DataFrame
import numpy as np #Linear Algebra
import datetime # Date Time
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

#SK-learn
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

#PCA
from sklearn.decomposition import PCA

# %% [markdown]
# # Load Data

# %%
train  = pd.read_csv('raw_data/train_data.csv')
test  = pd.read_csv('raw_data/test_data.csv')

# %%
train.head()
# Out:
#    index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      0  0.0  0.833333    9/1/14                              237.00
# 1      1  0.0  0.833333    9/2/14                              228.90
# 2      2  0.0  0.833333    9/3/14                              220.69
# 3      3  0.0  0.833333    9/4/14                              225.28
# 4      4  0.0  0.833333    9/5/14                              237.24
#
#    nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                     29.02                     31.64
# 1                     29.02                     31.64
# 2                     29.02                     31.64
# 3                     29.02                     31.64
# 4                     29.02                     31.64
#
#    nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  nmme0-tmp2m-34w__cfsv20  \
# 0                    29.57                    30.73                    29.71
# 1                    29.57                    30.73                    29.71
# 2                    29.57                    30.73                    29.71
# 3                    29.57                    30.73                    29.71
# 4                    29.57                    30.73                    29.71
#
#    ...  wind-vwnd-925-2010-11  wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  \
# 0  ...                 -27.68                 -37.21                   8.32
# 1  ...                 -21.13                 -36.57                   8.77
# 2  ...                 -10.72                 -34.16                   6.99
# 3  ...                   0.33                 -31.04                   6.17
# 4  ...                   9.83                 -31.80                   7.47
#
#    wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  \
# 0                   9.56                  -2.03                  48.13
# 1                  21.17                   4.44                  48.60
# 2                  32.16                   5.01                  48.53
# 3                  39.66                  -1.41                  50.59
# 4                  38.62                  -5.21                  54.73
#
#    wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  \
# 0                  28.09                 -13.50                  11.90
# 1                  27.41                 -23.77                  15.44
# 2                  19.21                 -33.16                  15.11
# 3                   8.29                 -37.22                  18.24
# 4                  -2.58                 -42.30                  21.91
#
#    wind-vwnd-925-2010-20
# 0                   4.58
# 1                   3.42
# 2                   4.82
# 3                   9.74
# 4                  10.95
#
# [5 rows x 246 columns]

# %%
test.head()
# Out:
#     index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0  375734  0.0  0.833333   11/1/22                              339.88
# 1  375735  0.0  0.833333   11/2/22                              334.63
# 2  375736  0.0  0.833333   11/3/22                              337.83
# 3  375737  0.0  0.833333   11/4/22                              345.81
# 4  375738  0.0  0.833333   11/5/22                              357.39
#
#    nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                     30.88                     30.92
# 1                     30.88                     30.92
# 2                     30.88                     30.92
# 3                     30.88                     30.92
# 4                     30.88                     30.92
#
#    nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  nmme0-tmp2m-34w__cfsv20  \
# 0                    29.17                    31.02                    29.47
# 1                    29.17                    31.02                    29.47
# 2                    29.17                    31.02                    29.47
# 3                    29.17                    31.02                    29.47
# 4                    29.17                    31.02                    29.47
#
#    ...  wind-vwnd-925-2010-11  wind-vwnd-925-2010-12  wind-vwnd-925-2010-13  \
# 0  ...                 -19.28                 -39.77                 -29.25
# 1  ...                 -19.58                 -43.14                 -28.62
# 2  ...                 -13.73                 -44.22                 -27.67
# 3  ...                  -7.97                 -49.47                 -19.32
# 4  ...                  -0.80                 -56.07                  -9.89
#
#    wind-vwnd-925-2010-14  wind-vwnd-925-2010-15  wind-vwnd-925-2010-16  \
# 0                  40.88                  -8.31                  14.91
# 1                  45.37                  -5.42                  16.97
# 2                  49.76                  -1.31                  21.44
# 3                  52.62                  -0.44                  21.65
# 4                  51.23                  -7.57                  19.86
#
#    wind-vwnd-925-2010-17  wind-vwnd-925-2010-18  wind-vwnd-925-2010-19  \
# 0                 -24.62                  31.05                 -23.69
# 1                 -23.94                  28.84                 -20.61
# 2                 -19.06                  26.85                 -16.78
# 3                 -23.12                  23.70                 -18.62
# 4                 -30.56                  20.66                 -25.08
#
#    wind-vwnd-925-2010-20
# 0                   6.27
# 1                  14.16
# 2                  13.42
# 3                  10.69
# 4                  19.64
#
# [5 rows x 245 columns]

# %%
target = [i for i in train.columns if i not in test.columns]
target
# Out:
# ['contest-tmp2m-14d__tmp2m']

# %% [markdown]
# # Describe Data

# %%
train.shape
# Out:
# (375734, 246)

# %%
test.shape
# Out:
# (31354, 245)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Columns: 246 entries, index to wind-vwnd-925-2010-20
# dtypes: float64(240), int64(4), object(2)
# memory usage: 705.2+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31354 entries, 0 to 31353
# Columns: 245 entries, index to wind-vwnd-925-2010-20
# dtypes: float64(241), int64(2), object(2)
# memory usage: 58.6+ MB

# %%
train.describe().T
# Out:
#                                        count           mean            std  \
# index                               375734.0  187866.500000  108465.207359
# lat                                 375734.0       0.592766       0.251744
# lon                                 375734.0       0.517964       0.272059
# contest-pevpr-sfc-gauss-14d__pevpr  375734.0     276.744064     198.085182
# nmme0-tmp2m-34w__cancm30            375734.0      10.801682      10.952417
# ...                                      ...            ...            ...
# wind-vwnd-925-2010-16               375734.0      -9.846867      34.164678
# wind-vwnd-925-2010-17               375734.0      -6.231860      27.050356
# wind-vwnd-925-2010-18               375734.0      16.014364      25.847455
# wind-vwnd-925-2010-19               375734.0      10.489945      25.070435
# wind-vwnd-925-2010-20               375734.0      11.296334      25.113214
#
#                                        min           25%            50%  \
# index                                 0.00  93933.250000  187866.500000
# lat                                   0.00      0.409091       0.590909
# lon                                   0.00      0.300000       0.533333
# contest-pevpr-sfc-gauss-14d__pevpr   -2.31    104.062500     250.320000
# nmme0-tmp2m-34w__cancm30            -14.96      1.550000       9.950000
# ...                                    ...           ...            ...
# wind-vwnd-925-2010-16              -106.08    -32.170000      -8.560000
# wind-vwnd-925-2010-17               -93.98    -20.170000      -6.030000
# wind-vwnd-925-2010-18               -52.61     -0.360000      18.650000
# wind-vwnd-925-2010-19               -66.11     -6.790000      11.860000
# wind-vwnd-925-2010-20               -57.61     -5.570000      11.650000
#
#                                               75%        max
# index                               281799.750000  375733.00
# lat                                      0.818182       1.00
# lon                                      0.766667       1.00
# contest-pevpr-sfc-gauss-14d__pevpr     420.010000    1185.14
# nmme0-tmp2m-34w__cancm30                20.230000      36.08
# ...                                           ...        ...
# wind-vwnd-925-2010-16                   10.500000      83.89
# wind-vwnd-925-2010-17                   11.630000      64.85
# wind-vwnd-925-2010-18                   31.210000      90.39
# wind-vwnd-925-2010-19                   29.040000      76.89
# wind-vwnd-925-2010-20                   29.180000      88.66
#
# [244 rows x 8 columns]

# %% [markdown]
# ## Missing Values

# %%
missing = []

# %%
for col in train.columns:
    na = train[col].isna().sum()
    if na>0:
        print('*'*25, '\n'+col,':')
        print(f"{na} missing values in column {col}")
        missing.append(col)
# Out:
# *************************
# nmme0-tmp2m-34w__ccsm30 :
# 15934 missing values in column nmme0-tmp2m-34w__ccsm30
# *************************
# nmme-tmp2m-56w__ccsm3 :
# 10280 missing values in column nmme-tmp2m-56w__ccsm3
# *************************
# nmme-prate-34w__ccsm3 :
# 8738 missing values in column nmme-prate-34w__ccsm3
# *************************
# nmme0-prate-56w__ccsm30 :
# 15934 missing values in column nmme0-prate-56w__ccsm30
# *************************
# nmme0-prate-34w__ccsm30 :
# 15934 missing values in column nmme0-prate-34w__ccsm30
# *************************
# nmme-prate-56w__ccsm3 :
# 10280 missing values in column nmme-prate-56w__ccsm3
# *************************
# nmme-tmp2m-34w__ccsm3 :
# 8738 missing values in column nmme-tmp2m-34w__ccsm3
# *************************
# ccsm30 :
# 15934 missing values in column ccsm30

# %%
for col in test.columns:
    na = test[col].isna().sum()
    if na>0:
        print('*'*25, '\n'+col,':')
        print(f"{na} missing values in column {col}")

# %% [markdown]
# ### FillNA with median

# %%
for i in missing:
    median = train[i].median()
    train[i] = train[i].fillna(median)

# %% [markdown]
# # Convert to Numerical Data

# %%
valid_types = ['float64','int64','uint8','datetime64[ns]']

# %%
for i in train.columns:
    dtype = train[i].dtype
    if dtype not in valid_types:
        print('*'*25)
        print(i)
        print(train[i].head())
# Out:
# *************************
# startdate
# 0    9/1/14
# 1    9/2/14
# 2    9/3/14
# 3    9/4/14
# 4    9/5/14
# Name: startdate, dtype: object
# *************************
# climateregions__climateregion
# 0    BSh
# 1    BSh
# 2    BSh
# 3    BSh
# 4    BSh
# Name: climateregions__climateregion, dtype: object

# %% [markdown]
# ### One Hot Encoding

# %% [markdown]
# #### Climate Regions

# %%
climate_regions = pd.get_dummies(train['climateregions__climateregion'])
train = train.join(climate_regions).drop('climateregions__climateregion',axis=1)

# %%
climate_regions = pd.get_dummies(test['climateregions__climateregion'])
test = test.join(climate_regions).drop('climateregions__climateregion',axis=1)

# %%
train.shape
# Out:
# (375734, 260)

# %% [markdown]
# #### StartDate

# %%
train['startdate'] = pd.to_datetime(train['startdate'], format = '%m/%d/%y')
ref_date = datetime.datetime(2014, 9, 1)  # Example reference point
train['date'] = (train['startdate'] - ref_date).dt.days
train = train.drop('startdate',axis=1)

# %%
test['startdate'] = pd.to_datetime(test['startdate'], format = '%m/%d/%y')
ref_date = datetime.datetime(2014, 9, 1)  # Example reference point
test['date'] = (test['startdate'] - ref_date).dt.days
test = test.drop('startdate',axis=1)

# %% [markdown]
# #### Recheck

# %%
for i in train.columns:
    dtype = train[i].dtype
    if dtype not in valid_types:
        print('*'*25)
        print(i)
        print(train[i].head())

# %% [markdown]
# # PCA

# %% [markdown]
# #### Scale Data

# %%
data_scaled = train.copy(deep=True)

# %%
scaler = StandardScaler()
data_scaled = pd.DataFrame(scaler.fit_transform(data_scaled),columns=data_scaled.columns)
data_scaled.head()
# Out:
#       index       lat       lon  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0 -1.732046 -2.354642  1.159198                           -0.200642
# 1 -1.732037 -2.354642  1.159198                           -0.241533
# 2 -1.732028 -2.354642  1.159198                           -0.282980
# 3 -1.732019 -2.354642  1.159198                           -0.259808
# 4 -1.732009 -2.354642  1.159198                           -0.199430
#
#    nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                  1.663408                  1.707969
# 1                  1.663408                  1.707969
# 2                  1.663408                  1.707969
# 3                  1.663408                  1.707969
# 4                  1.663408                  1.707969
#
#    nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  nmme0-tmp2m-34w__cfsv20  \
# 0                 1.926773                 1.805495                 2.018001
# 1                 1.926773                 1.805495                 2.018001
# 2                 1.926773                 1.805495                 2.018001
# 3                 1.926773                 1.805495                 2.018001
# 4                 1.926773                 1.805495                 2.018001
#
#    nmme0-tmp2m-34w__gfdlflora0  ...       Csa       Csb       Dfa       Dfb  \
# 0                     1.847282  ... -0.161084 -0.349672 -0.253342 -0.403604
# 1                     1.847282  ... -0.161084 -0.349672 -0.253342 -0.403604
# 2                     1.847282  ... -0.161084 -0.349672 -0.253342 -0.403604
# 3                     1.847282  ... -0.161084 -0.349672 -0.253342 -0.403604
# 4                     1.847282  ... -0.161084 -0.349672 -0.253342 -0.403604
#
#         Dfc       Dsb       Dsc     Dwa       Dwb      date
# 0 -0.184947 -0.147881 -0.088561 -0.0625 -0.044151 -1.729683
# 1 -0.184947 -0.147881 -0.088561 -0.0625 -0.044151 -1.724944
# 2 -0.184947 -0.147881 -0.088561 -0.0625 -0.044151 -1.720205
# 3 -0.184947 -0.147881 -0.088561 -0.0625 -0.044151 -1.715466
# 4 -0.184947 -0.147881 -0.088561 -0.0625 -0.044151 -1.710728
#
# [5 rows x 260 columns]

# %%
n = data_scaled.shape[1]

pca = PCA(n_components=n, random_state=1)
data_pc1 = pd.DataFrame(pca.fit_transform(data_scaled))

exp_var = pca.explained_variance_ratio_

# %%
plt.figure(figsize = (10,10))
plt.plot(range(1,261), exp_var.cumsum(), marker = 'o', linestyle = '--')
plt.title("Explained Variances by Components")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %%
sum = 0
for ix, i in enumerate(exp_var):
  sum = sum + i
  if(sum>0.95):
    print("Number of PCs that explain at least 95% variance: ", ix+1)
    break
# Out:
# Number of PCs that explain at least 95% variance:  60

# %%
pc_comps = ['PC1','PC2','PC3']
data_pca = pd.DataFrame(np.round(pca.components_[:3,:],2),index=pc_comps,columns=data_scaled.columns)
data_pca = data_pca.T.sort_values("PC1", ascending=False)

# %%
def color_high(val):
    if val <= -0.1: # you can decide any value as per your understanding
        return 'background: pink'
    elif val >= 0.1:
        return 'background: skyblue'   

data_pca.style.applymap(color_high)
# Out:
# <style type="text/css">
# #T_a82c3_row0_col0, #T_a82c3_row1_col0, #T_a82c3_row2_col0, #T_a82c3_row3_col0, #T_a82c3_row4_col0, #T_a82c3_row5_col0, #T_a82c3_row6_col0, #T_a82c3_row7_col0, #T_a82c3_row8_col0, #T_a82c3_row9_col0, #T_a82c3_row10_col0, #T_a82c3_row11_col0, #T_a82c3_row12_col0, #T_a82c3_row13_col0, #T_a82c3_row14_col0, #T_a82c3_row15_col0, #T_a82c3_row16_col0, #T_a82c3_row17_col0, #T_a82c3_row18_col0, #T_a82c3_row19_col0, #T_a82c3_row20_col0, #T_a82c3_row21_col0, #T_a82c3_row22_col0, #T_a82c3_row23_col0, #T_a82c3_row24_col0, #T_a82c3_row25_col0, #T_a82c3_row26_col0, #T_a82c3_row27_col0, #T_a82c3_row28_col0, #T_a82c3_row29_col0, #T_a82c3_row30_col0, #T_a82c3_row31_col0, #T_a82c3_row32_col0, #T_a82c3_row33_col0, #T_a82c3_row34_col0, #T_a82c3_row35_col0, #T_a82c3_row36_col0, #T_a82c3_row37_col0, #T_a82c3_row38_col0, #T_a82c3_row39_col0, #T_a82c3_row40_col0, #T_a82c3_row40_col2, #T_a82c3_row41_col0, #T_a82c3_row42_col0, #T_a82c3_row43_col0, #T_a82c3_row44_col0, #T_a82c3_row45_col0, #T_a82c3_row46_col0, #T_a82c3_row47_col0, #T_a82c3_row64_col2, #T_a82c3_row66_col2, #T_a82c3_row72_col2, #T_a82c3_row84_col2, #T_a82c3_row120_col1, #T_a82c3_row123_col1, #T_a82c3_row124_col2, #T_a82c3_row136_col1, #T_a82c3_row148_col2, #T_a82c3_row157_col1, #T_a82c3_row158_col2, #T_a82c3_row160_col2, #T_a82c3_row163_col1, #T_a82c3_row164_col2, #T_a82c3_row166_col1, #T_a82c3_row167_col1, #T_a82c3_row171_col1, #T_a82c3_row177_col1, #T_a82c3_row178_col1, #T_a82c3_row180_col1, #T_a82c3_row182_col1, #T_a82c3_row184_col1, #T_a82c3_row185_col2, #T_a82c3_row190_col1, #T_a82c3_row194_col1, #T_a82c3_row197_col1, #T_a82c3_row200_col1, #T_a82c3_row201_col1, #T_a82c3_row202_col1, #T_a82c3_row203_col1, #T_a82c3_row207_col1, #T_a82c3_row208_col1, #T_a82c3_row209_col1, #T_a82c3_row210_col1, #T_a82c3_row211_col1, #T_a82c3_row213_col1, #T_a82c3_row214_col1, #T_a82c3_row227_col1, #T_a82c3_row228_col1, #T_a82c3_row229_col2, #T_a82c3_row230_col1, #T_a82c3_row231_col1, #T_a82c3_row232_col1, #T_a82c3_row234_col1, #T_a82c3_row236_col1, #T_a82c3_row239_col1, #T_a82c3_row241_col1, #T_a82c3_row243_col1, #T_a82c3_row244_col1, #T_a82c3_row246_col1, #T_a82c3_row247_col1, #T_a82c3_row248_col1 {
#   background: skyblue;
# }
# #T_a82c3_row55_col2, #T_a82c3_row67_col2, #T_a82c3_row73_col2, #T_a82c3_row106_col2, #T_a82c3_row116_col2, #T_a82c3_row125_col2, #T_a82c3_row137_col2, #T_a82c3_row142_col2, #T_a82c3_row144_col2, #T_a82c3_row154_col2, #T_a82c3_row206_col2, #T_a82c3_row219_col2, #T_a82c3_row221_col2, #T_a82c3_row252_col0, #T_a82c3_row252_col2, #T_a82c3_row253_col0, #T_a82c3_row254_col0, #T_a82c3_row255_col0, #T_a82c3_row256_col0, #T_a82c3_row257_col0, #T_a82c3_row258_col0, #T_a82c3_row259_col0 {
#   background: pink;
# }
# </style>
# <table id="T_a82c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a82c3_level0_col0" class="col_heading level0 col0" >PC1</th>
#       <th id="T_a82c3_level0_col1" class="col_heading level0 col1" >PC2</th>
#       <th id="T_a82c3_level0_col2" class="col_heading level0 col2" >PC3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a82c3_level0_row0" class="row_heading level0 row0" >nmme0-tmp2m-34w__nmme0mean</th>
#       <td id="T_a82c3_row0_col0" class="data row0 col0" >0.130000</td>
#       <td id="T_a82c3_row0_col1" class="data row0 col1" >0.010000</td>
#       <td id="T_a82c3_row0_col2" class="data row0 col2" >0.050000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row1" class="row_heading level0 row1" >nmme-tmp2m-34w__gfdlflora</th>
#       <td id="T_a82c3_row1_col0" class="data row1 col0" >0.120000</td>
#       <td id="T_a82c3_row1_col1" class="data row1 col1" >0.050000</td>
#       <td id="T_a82c3_row1_col2" class="data row1 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row2" class="row_heading level0 row2" >nmme-tmp2m-34w__nasa</th>
#       <td id="T_a82c3_row2_col0" class="data row2 col0" >0.120000</td>
#       <td id="T_a82c3_row2_col1" class="data row2 col1" >0.040000</td>
#       <td id="T_a82c3_row2_col2" class="data row2 col2" >-0.040000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row3" class="row_heading level0 row3" >nmme-tmp2m-56w__gfdlflora</th>
#       <td id="T_a82c3_row3_col0" class="data row3 col0" >0.120000</td>
#       <td id="T_a82c3_row3_col1" class="data row3 col1" >0.050000</td>
#       <td id="T_a82c3_row3_col2" class="data row3 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row4" class="row_heading level0 row4" >nmme0mean</th>
#       <td id="T_a82c3_row4_col0" class="data row4 col0" >0.120000</td>
#       <td id="T_a82c3_row4_col1" class="data row4 col1" >-0.010000</td>
#       <td id="T_a82c3_row4_col2" class="data row4 col2" >0.090000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row5" class="row_heading level0 row5" >nmme-tmp2m-56w__nasa</th>
#       <td id="T_a82c3_row5_col0" class="data row5 col0" >0.120000</td>
#       <td id="T_a82c3_row5_col1" class="data row5 col1" >0.040000</td>
#       <td id="T_a82c3_row5_col2" class="data row5 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row6" class="row_heading level0 row6" >nmme-tmp2m-56w__nmmemean</th>
#       <td id="T_a82c3_row6_col0" class="data row6 col0" >0.120000</td>
#       <td id="T_a82c3_row6_col1" class="data row6 col1" >0.050000</td>
#       <td id="T_a82c3_row6_col2" class="data row6 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row7" class="row_heading level0 row7" >nmme-tmp2m-34w__gfdl</th>
#       <td id="T_a82c3_row7_col0" class="data row7 col0" >0.120000</td>
#       <td id="T_a82c3_row7_col1" class="data row7 col1" >0.050000</td>
#       <td id="T_a82c3_row7_col2" class="data row7 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row8" class="row_heading level0 row8" >nmme-tmp2m-34w__gfdlflorb</th>
#       <td id="T_a82c3_row8_col0" class="data row8 col0" >0.120000</td>
#       <td id="T_a82c3_row8_col1" class="data row8 col1" >0.050000</td>
#       <td id="T_a82c3_row8_col2" class="data row8 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row9" class="row_heading level0 row9" >nmme-tmp2m-34w__nmmemean</th>
#       <td id="T_a82c3_row9_col0" class="data row9 col0" >0.120000</td>
#       <td id="T_a82c3_row9_col1" class="data row9 col1" >0.050000</td>
#       <td id="T_a82c3_row9_col2" class="data row9 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row10" class="row_heading level0 row10" >nmme-tmp2m-56w__cfsv2</th>
#       <td id="T_a82c3_row10_col0" class="data row10 col0" >0.120000</td>
#       <td id="T_a82c3_row10_col1" class="data row10 col1" >0.040000</td>
#       <td id="T_a82c3_row10_col2" class="data row10 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row11" class="row_heading level0 row11" >cancm30</th>
#       <td id="T_a82c3_row11_col0" class="data row11 col0" >0.120000</td>
#       <td id="T_a82c3_row11_col1" class="data row11 col1" >-0.000000</td>
#       <td id="T_a82c3_row11_col2" class="data row11 col2" >0.090000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row12" class="row_heading level0 row12" >contest-tmp2m-14d__tmp2m</th>
#       <td id="T_a82c3_row12_col0" class="data row12 col0" >0.120000</td>
#       <td id="T_a82c3_row12_col1" class="data row12 col1" >0.050000</td>
#       <td id="T_a82c3_row12_col2" class="data row12 col2" >-0.030000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row13" class="row_heading level0 row13" >wind-uwnd-925-2010-1</th>
#       <td id="T_a82c3_row13_col0" class="data row13 col0" >0.120000</td>
#       <td id="T_a82c3_row13_col1" class="data row13 col1" >0.020000</td>
#       <td id="T_a82c3_row13_col2" class="data row13 col2" >-0.020000</td>
#     </tr>
#     <tr>
#       <th id="T_a82c3_level0_row14" class="row_heading level0 row14" >contest-wind-h100-14d__wind-hgt-100</th>
#       <td id="T_a82c3_row14_col0" class="data row14 col0" >0.120000</td>
#       <td id="T_a82c3_row14_col1" class="data row14 col1" >0.020000</td>
#       <td id="T_a82c3_row14_col2" class="data r

# %%
features = list(data_pca.head(50).index)
len(features)
# Out:
# 50

# %%
target
# Out:
# ['contest-tmp2m-14d__tmp2m']

# %%
new_train = pd.concat([train['index'],train[target],train[features].drop('contest-tmp2m-14d__tmp2m',axis=1)],axis=1)
new_train.head()
# Out:
#    index  contest-tmp2m-14d__tmp2m  nmme0-tmp2m-34w__nmme0mean  \
# 0      0                 28.744480                       30.46
# 1      1                 28.370585                       30.46
# 2      2                 28.133059                       30.46
# 3      3                 28.256798                       30.46
# 4      4                 28.372353                       30.46
#
#    nmme-tmp2m-34w__gfdlflora  nmme-tmp2m-34w__nasa  nmme-tmp2m-56w__gfdlflora  \
# 0                      28.42                 28.55                       27.7
# 1                      28.42                 28.55                       27.7
# 2                      28.42                 28.55                       27.7
# 3                      28.42                 28.55                       27.7
# 4                      28.42                 28.55                       27.7
#
#    nmme0mean  nmme-tmp2m-56w__nasa  nmme-tmp2m-56w__nmmemean  \
# 0      30.65                 28.38                     28.11
# 1      30.65                 28.38                     28.11
# 2      30.65                 28.38                     28.11
# 3      30.65                 28.38                     28.11
# 4      30.65                 28.38                     28.11
#
#    nmme-tmp2m-34w__gfdl  ...  ccsm40  gfdlflora0  gfdlflorb0  gfdl0  \
# 0                 28.27  ...   30.73       31.66       31.45  31.33
# 1                 28.27  ...   30.73       31.66       31.45  31.33
# 2                 28.27  ...   30.73       31.66       31.45  31.33
# 3                 28.27  ...   30.73       31.66       31.45  31.33
# 4                 28.27  ...   30.73       31.66       31.45  31.33
#
#    nmme-tmp2m-34w__ccsm3  sst-2010-1  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0                  27.57      352.20                              237.00
# 1                  27.57      350.96                              228.90
# 2                  27.57      349.86                              220.69
# 3                  27.57      348.91                              225.28
# 4                  27.57      348.03                              237.24
#
#    contest-wind-h10-14d__wind-hgt-10  contest-prwtr-eatm-14d__prwtr  \
# 0                           31246.63                          42.45
# 1                           31244.78                          42.66
# 2                           31239.27                          43.23
# 3                           31232.86                          43.11
# 4                           31226.16                          42.98
#
#    icec-2010-9
# 0         0.03
# 1         0.03
# 2         0.03
# 3         0.03
# 4         0.03
#
# [5 rows x 51 columns]

# %%
test_features = [i for i in features if i!='contest-tmp2m-14d__tmp2m']

new_test = pd.concat([test['index'],test[test_features]],axis=1)
new_test.head()
# Out:
#     index  nmme0-tmp2m-34w__nmme0mean  nmme-tmp2m-34w__gfdlflora  \
# 0  375734                       30.37                      28.28
# 1  375735                       30.37                      28.28
# 2  375736                       30.37                      28.28
# 3  375737                       30.37                      28.28
# 4  375738                       30.37                      28.28
#
#    nmme-tmp2m-34w__nasa  nmme-tmp2m-56w__gfdlflora  nmme0mean  \
# 0                 27.94                      26.82      30.77
# 1                 27.94                      26.82      30.77
# 2                 27.94                      26.82      30.77
# 3                 27.94                      26.82      30.77
# 4                 27.94                      26.82      30.77
#
#    nmme-tmp2m-56w__nasa  nmme-tmp2m-56w__nmmemean  nmme-tmp2m-34w__gfdl  \
# 0                 27.96                     27.81                 27.79
# 1                 27.96                     27.81                 27.79
# 2                 27.96                     27.81                 27.79
# 3                 27.96                     27.81                 27.79
# 4                 27.96                     27.81                 27.79
#
#    nmme-tmp2m-34w__gfdlflorb  ...  ccsm40  gfdlflora0  gfdlflorb0  gfdl0  \
# 0                      27.83  ...   31.58       31.71       31.84  31.49
# 1                      27.83  ...   31.58       31.71       31.84  31.49
# 2                      27.83  ...   31.58       31.71       31.84  31.49
# 3                      27.83  ...   31.58       31.71       31.84  31.49
# 4                      27.83  ...   31.58       31.71       31.84  31.49
#
#    nmme-tmp2m-34w__ccsm3  sst-2010-1  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0                  27.37      345.33                              339.88
# 1                  27.37      344.50                              334.63
# 2                  27.37      343.40                              337.83
# 3                  27.37      341.91                              345.81
# 4                  27.37      340.22                              357.39
#
#    contest-wind-h10-14d__wind-hgt-10  contest-prwtr-eatm-14d__prwtr  \
# 0                           31233.02                          40.29
# 1                           31230.63                          40.15
# 2                           31225.26                          40.07
# 3                           31220.87                          40.00
# 4                           31214.54                          39.80
#
#    icec-2010-9
# 0         0.03
# 1         0.03
# 2         0.03
# 3         0.03
# 4         0.03
#
# [5 rows x 50 columns]

# %%
train.to_csv('new_data/full_train.csv',index=False)
test.to_csv('new_data/full_test.csv', index=False)

# %%
new_train.to_csv('new_data/train.csv',index=False)
new_test.to_csv('new_data/test.csv', index=False)
